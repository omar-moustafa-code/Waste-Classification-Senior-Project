# %% [markdown]
# # These Work - Jan 13 - Xception V2

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import os
import random
from pathlib import Path
from PIL import Image
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import kagglehub
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# ## Loading the Dataset's Kaggle Path

# %%
import kagglehub
from pathlib import Path

path = kagglehub.dataset_download(
    "wasifmahmood01/custom-waste-classification-dataset"
)

print("Dataset downloaded to:", path)
# Out:
# ...
# 100%|██████████| 5.39G/5.39G [00:58<00:00, 98.2MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/wasifmahmood01/custom-waste-classification-dataset/versions/1

# %%
for root, dirs, files in os.walk(path):
    print(root)
    break
# Out:
# /root/.cache/kagglehub/datasets/wasifmahmood01/custom-waste-classification-dataset/versions/1

# %%
for d in os.listdir(path):
    print(d)
# Out:
# wastes

# %%
data_dir = Path(path) / "wastes"

train_dir = data_dir / "train"
test_dir  = data_dir / "test"

print("Train exists:", train_dir.exists())
print("Test exists:", test_dir.exists())
# Out:
# Train exists: True
# Test exists: True

# %% [markdown]
# ## Adding Generators

# %%
# Dataset directory paths (ADJUST ONLY IF YOUR FOLDER NAMES DIFFER)

TRAIN_DIR = "/root/.cache/kagglehub/datasets/wasifmahmood01/custom-waste-classification-dataset/versions/1/wastes/train"
VAL_DIR   = "/root/.cache/kagglehub/datasets/wasifmahmood01/custom-waste-classification-dataset/versions/1/wastes/test"

import os
print("Train classes:", os.listdir(TRAIN_DIR))
print("Val classes:", os.listdir(VAL_DIR))
# Out:
# Train classes: ['organic waste', 'glass waste', 'automobile wastes', 'E-waste', 'light bulbs', 'paper waste', 'plastic waste', 'metal waste', 'battery waste']
# Val classes: ['organic waste', 'glass waste', 'automobile wastes', 'E-waste', 'light bulbs', 'paper waste', 'plastic waste', 'metal waste', 'battery waste']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import preprocess_input

BATCH_SIZE = 32
IMG_SIZE = (299, 299)

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

num_classes = train_gen.num_classes
# Out:
# Found 9214 images belonging to 9 classes.
# Found 2308 images belonging to 9 classes.

# %%
print("Class indices:")
for k, v in train_gen.class_indices.items():
    print(f"{v}: {k}")
# Out:
# Class indices:
# 0: E-waste
# 1: automobile wastes
# 2: battery waste
# 3: glass waste
# 4: light bulbs
# 5: metal waste
# 6: organic waste
# 7: paper waste
# 8: plastic waste

# %% [markdown]
# ## Build & Train Xception Model

# %%
import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import (
    Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
)
from tensorflow.keras.models import Model

base_model = Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(299, 299, 3)
)

# Freeze all backbone layers initially
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)

x = Dense(
    256,
    activation="relu",
    kernel_regularizer=tf.keras.regularizers.l2(1e-4)
)(x)

x = Dropout(0.5)(x)

outputs = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.summary()
# Out:
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 149, 149,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 149, 149,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ...

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1
    )
]

# %%
history_frozen = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 473s 2s/step - accuracy: 0.6036 - loss: 1.4534 - val_accuracy: 0.8215 - val_loss: 0.6194 - learning_rate: 0.0010
# Epoch 2/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 375s 1s/step - accuracy: 0.7626 - loss: 0.8032 - val_accuracy: 0.8475 - val_loss: 0.5401 - learning_rate: 0.0010
# Epoch 3/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 378s 1s/step - accuracy: 0.8142 - loss: 0.6248 - val_accuracy: 0.8536 - val_loss: 0.5278 - learning_rate: 0.0010
# Epoch 4/10
# ...

# %%
frozen_train_acc = max(history_frozen.history['accuracy'])
frozen_val_acc = max(history_frozen.history['val_accuracy'])

print(f"Best Frozen Train Accuracy: {frozen_train_acc*100:.2f}%")
print(f"Best Frozen Validation Accuracy:   {frozen_val_acc*100:.2f}%")
# Out:
# Best Frozen Train Accuracy: 88.72%
# Best Frozen Validation Accuracy:   88.43%

# %%
val_gen.reset()
y_true = val_gen.classes
y_pred = model.predict(val_gen)
y_pred_classes = np.argmax(y_pred, axis=1)

print("Frozen Xception Model Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=val_gen.class_indices.keys()))

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=val_gen.class_indices.keys(),
            yticklabels=val_gen.class_indices.keys())
plt.title("Frozen Xception Model – Confusion Matrix")
plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 62s 690ms/step
# Frozen Xception Model Classification Report:
#                    precision    recall  f1-score   support
#
#           E-waste       0.88      0.92      0.90       313
# automobile wastes       0.89      0.91      0.90       218
#     battery waste       0.90      0.88      0.89       213
#       glass waste       0.90      0.86      0.88       256
#       light bulbs       0.93      0.90      0.91       105
#       metal waste       0.80      0.87      0.84       308
#     organic waste       0.92      0.90      0.91       223
#       paper waste       0.95      0.87      0.91       343
#     plastic waste       0.83      0.85      0.84       329
#
#          accuracy                           0.88      2308
#         macro avg       0.89      0.88      0.89      2308
#      weighted avg       0.88      0.88      0.88      2308

# %%
y_pred_classes = np.argmax(y_pred, axis=1)

# calculate the F1 score using the converted labels
macro_f1 = f1_score(y_true, y_pred_classes, average="macro")

print(f"Final Macro F1 Score - Frozen Xception Model: {macro_f1:.4f}")
# Out:
# Final Macro F1 Score - Frozen Xception Model: 0.8861

# %%
plt.plot(history_frozen.history["accuracy"], label="Train")
plt.plot(history_frozen.history["val_accuracy"], label="Validation")
plt.title("Frozen Xception Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Fine-Tuning Xception Model

# %%
# Freeze everything
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze just the last 20 layers
for layer in base_model.layers[-20:]:
    layer.trainable = True

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_finetune = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 445s 1s/step - accuracy: 0.8586 - loss: 0.5210 - val_accuracy: 0.8778 - val_loss: 0.5231 - learning_rate: 1.0000e-05
# Epoch 2/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.8797 - loss: 0.4506 - val_accuracy: 0.8817 - val_loss: 0.5080 - learning_rate: 1.0000e-05
# Epoch 3/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 377s 1s/step - accuracy: 0.8825 - loss: 0.4288 - val_accuracy: 0.8847 - val_loss: 0.4989 - learning_rate: 1.0000e-05
# Epoch 4/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 377s 1s/step - accuracy: 0.8954 - loss: 0.3935 - val_accuracy: 0.8891 - val_loss: 0.4894 - learning_rate: 1.0000e-05
# Epoch 5/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 376s 1s/step - accuracy: 0.8996 - loss: 0.3936 - val_accuracy: 0.8886 - val_loss: 0.4797 - learning_rate: 1.0000e-05
# Epoch 6/10
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 378s 1s/step - accuracy: 0.9071 - loss: 0.3619 - val_accuracy: 0.8899 - val_loss: 0.4751 - learning_rate: 1.0000e-05
# Epoch 7/10
# ...

# %%
ft_train_acc = max(history_finetune.history['accuracy'])
ft_val_acc = max(history_finetune.history['val_accuracy'])

print(f"Best Fine-Tuned Train Accuracy: {ft_train_acc*100:.2f}%")
print(f"Best Fine-Tuned Validation Accuracy:   {ft_val_acc*100:.2f}%")
# Out:
# Best Fine-Tuned Train Accuracy: 91.77%
# Best Fine-Tuned Validation Accuracy:   89.86%

# %%
val_gen.reset()
y_pred = model.predict(val_gen)
y_pred_classes = np.argmax(y_pred, axis=1)

print("Fine-Tuned Xception Model Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=val_gen.class_indices.keys()))

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=val_gen.class_indices.keys(),
            yticklabels=val_gen.class_indices.keys())
plt.title("Fine-Tuned Xception Model – Confusion Matrix")
plt.ylabel("True")
plt.xlabel("Predicted")
plt.show()
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 63s 708ms/step
# Fine-Tuned Xception Model Classification Report:
#                    precision    recall  f1-score   support
#
#           E-waste       0.90      0.93      0.92       313
# automobile wastes       0.88      0.91      0.90       218
#     battery waste       0.92      0.91      0.91       213
#       glass waste       0.95      0.88      0.91       256
#       light bulbs       0.91      0.89      0.90       105
#       metal waste       0.84      0.87      0.85       308
#     organic waste       0.93      0.93      0.93       223
#       paper waste       0.97      0.91      0.94       343
#     plastic waste       0.83      0.87      0.85       329
#
#          accuracy                           0.90      2308
#         macro avg       0.90      0.90      0.90      2308
#      weighted avg       0.90      0.90      0.90      2308

# %%
y_pred_classes = np.argmax(y_pred, axis=1)

# calculate the F1 score using the converted labels
macro_f1 = f1_score(y_true, y_pred_classes, average="macro")

print(f"Final Macro F1 Score - Fine-Tuned Xception Model: {macro_f1:.4f}")
# Out:
# Final Macro F1 Score - Fine-Tuned Xception Model: 0.9004

# %%
plt.plot(history_finetune.history["accuracy"], label="Train")
plt.plot(history_finetune.history["val_accuracy"], label="Validation")
plt.title("Fine-Tuned Xception Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# Due to stochastic training effects, slight variations in trainiong and validation accuracies were observed across repeated runs. However, overall performance remained stable, with validation accuracy consistently around 90%, confirming the robustness of this Xception model.

# %% [markdown]
# ## Model Saving

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
SAVE_DIR = "/content/drive/MyDrive/Thesis_Models"
os.makedirs(SAVE_DIR, exist_ok=True)

print("Directory ready:", SAVE_DIR)
# Out:
# Directory ready: /content/drive/MyDrive/Thesis_Models

# %%
MODEL_SAVE_PATH = "/content/drive/MyDrive/Thesis_Models/xception_finetuned.keras"

model.save(MODEL_SAVE_PATH)

print("Model successfully saved to:", MODEL_SAVE_PATH)
# Out:
# Model successfully saved to: /content/drive/MyDrive/Thesis_Models/xception_finetuned.keras

# %%
from tensorflow.keras.models import load_model

test_model = load_model("/content/drive/MyDrive/Thesis_Models/xception_finetuned.keras")
test_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 149, 149,  │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 149, 149,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
